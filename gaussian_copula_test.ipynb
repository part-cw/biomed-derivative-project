# %%
from sdv.demo import load_tabular_demo
from sdv.tabular import GaussianCopula

# %%
real_data = load_tabular_demo('student_placements')

# %%
model = GaussianCopula()

# %%
model.fit(real_data)
# Out:
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\scipy\stats\_continuous_distns.py:5320: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\scipy\stats\_distn_infrastructure.py:2606: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\scipy\stats\_continuous_distns.py:639: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\scipy\optimize\minpack.py:175: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# ...

# %%
synthetic_data = model.sample()

# %%
real_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17264      M        67.00      91.00  Commerce        58.00
# 1       17265      M        79.33      78.33   Science        77.48
# 2       17266      M        65.00      68.00      Arts        64.00
# 3       17267      M        56.00      52.00   Science        52.00
# 4       17268      M        85.80      73.60  Commerce        73.30
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0    Sci&Tech            False                 0                55.0   Mkt&HR
# 1    Sci&Tech             True                 1                86.5  Mkt&Fin
# 2   Comm&Mgmt            False                 0                75.0  Mkt&Fin
# 3    Sci&Tech            False                 0                66.0   Mkt&HR
# 4   Comm&Mgmt            False                 0                96.8  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date  duration
# ...

# %%
synthetic_data.head()
# Out:
#    student_id gender  second_perc  high_perc high_spec  degree_perc  \
# 0       17333      F        71.24      72.00   Science        71.71
# 1       17344      M        76.44      69.00  Commerce        69.40
# 2       17369      M        70.86      67.40  Commerce        66.83
# 3       17361      F        84.87      67.64   Science        69.67
# 4       17393      M        42.42      48.10  Commerce        61.71
#
#   degree_type  work_experience  experience_years  employability_perc mba_spec  \
# 0   Comm&Mgmt            False                 1               68.82   Mkt&HR
# 1   Comm&Mgmt            False                 1               63.07  Mkt&Fin
# 2   Comm&Mgmt            False                 0               50.57  Mkt&Fin
# 3    Sci&Tech            False                 1               58.52  Mkt&Fin
# 4   Comm&Mgmt            False                 1               83.78  Mkt&Fin
#
#    mba_perc   salary  placed start_date   end_date  duration
# ...

# %%
from sdv.evaluation import evaluate

# %%
evaluate(synthetic_data, real_data, aggregate=False)
# Out:
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\sklearn\mixture\_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\sklearn\mixture\_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# c:\Users\Artem\Desktop\General\Biomed\tests\lib\site-packages\sklearn\mixture\_base.py:282: ConvergenceWarning: Initialization 1 did not converge. Try different init parameters, or increase max_iter, tol or check for degenerate data.
#   ConvergenceWarning,
# ...

# %%
evaluate(synthetic_data, real_data, aggregate=False, metrics=['KSTest'])
# Out:
#    metric                                     name  raw_score  \
# 0  KSTest  Inverted Kolmogorov-Smirnov D statistic   0.918346
#
#    normalized_score  min_value  max_value      goal error
# 0          0.918346        0.0        1.0  MAXIMIZE  None
