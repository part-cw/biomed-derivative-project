# %%
import pandas as pd
import numpy as np

# %%
real = pd.read_csv('datasets/real_data.csv')

# %%
for r in real.columns:
    for v in real[r]:
        if v == '?':
            print(r)
# Out:
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# STDs: Time since last diagnosis
# ...
